# %% [markdown]
# ## Домашнее задание 2 (1.7 балла + 0.2 балла бонус). Проверка нормальности. Многовариантное тестирование

# %% [markdown]
# **Оформление дз**:
#
# - Task short name: ``StatsSecond``.
# - Выполненное дз сохраните в файл ``ML2018_<фамилия>_HW#.ipynb``, к примеру -- ``ML2018_ivanov_HW2.ipynb``
# - Присылайте выполненное задание на почту <a href="mailto:ml4megafon_2018_08@bigdatateam.org"> ml4megafon_2018_08@bigdatateam.org</a> с темой письма `` HW# Short name. ФИО ``.
#
#     Например: `` HW2 StatsSecond. Иванов Иван Иванович. ``
#
# **Вопросы**:
# - Свои вопросы присылайте в Telegram.
#
# **Фидбек**:
# - Пожалуйста, оставьте свой отзыв после выполнения домашнего задания по сссылке:
#
#    http://bit.ly/ml4megafon_august18_hw2_feedback

# %% [markdown]
# ## Задача 1 (0.3 балла)

# %% [markdown]
# Рассмотрим датасет Wine (`wine.data`, семинар 2).
#
# Найдите распределение, которому принадлежит столбец `Alcalinity of ash`. Интерпретируйте результаты при помощи qq-plot, ks-test, критерия Андерсона-Дарлинга, Шапиро-Уилка.

# %% [markdown]
# ## Задача 2 (0.4 балла + 0.2 бонус)

# %% [markdown]
# Рассмотрим датасет Ame Housing (`train_normal.csv`, семинар 2)
#
# Найдите, какому распределению принадлежат столбцы `TotalBsmtSF` и `GrLivArea`.
#
#
# <b>Подсказка.</b> Не забудьте произвести предварительную обработку данных.
#
# <b>Примечание. </b> За каждый приведенный неотвергнутый критерий принадлежности ставится 0.2 балла. Два критерия можно найти применением рассмотренных на семинарах критериях, а для нахождения третьего критерия стоит проявить фантазию.
#
#
# В случае применения критерия хи-квадрат объясните, почему при проверке гипотезы используются указанные вами интервалы.

# %% [markdown]
# ## Задача 3 (1 балл)

# %% [markdown]
# Выкачайте архив с данными многовариантного тестирования кликов пользователей на 5 разных вариантах главной страницы сайта (http://bit.ly/ml4megafon_august18_hw2_stats_data).
#
# В каждом из PDF файлов найдите данные по кликам на странице относительно разных версий браузера (седьмая страница) и ширины окна (последняя страница)
#
# Решите следующие задачи:
#
# 1. (0.3 балла) Проверьте гипотезу о том, что распределение кликов по самым популяным браузерам не отличаются друг от друга (список значимых браузеров определите самостоятельно - не менее 3 браузеров). Проведите аналогичные исследования для ширины окна.
#
# 2. (0.3 балла) Выберите самый популярный браузер среди всех вариантов A/B тестирования. Проверьте гипотезу о том, есть ли значимое отличие по доле кликов с этого браузера в различных вариантах тестирования. Проведите аналогичные исследования для ширины окна.
#
# 3. (0.4 балла) При помощи процедуры множественной проверки гипотез упорядочите разные версии сайта по доле кликабельности для пользователей самого популярного браузера. Обоснуйте выбранный способ проведения процедуры. Проведите аналогичные исследования для ширины окна.
