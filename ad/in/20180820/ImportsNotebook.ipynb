# %%
import numpy as np
import statsmodels
import scipy.stats
import sklearn
import matplotlib.pyplot
import seaborn as sns
import xlrd
import tqdm
import pandas as pd
# %matplotlib inline

# %%
# !pip install tqdm
# Out:
# ...
#     100% |████████████████████████████████| 51kB 3.5MB/s
# ...
